# %% [markdown]
# # 导入库

# %%
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).parent.parent)

# %%
os.getcwd()
# Out:
# 'D:\\LFProjects\\NewPythonProject'

# %%
from factor_test.base import BaseFactorTest

# %% [markdown]
# # 因子测试BaseFactorTest

# %% [markdown]
# ## 初始化和设置因子

# %%
# 初始化BaseFactorTest
self = BaseFactorTest()
# 设置因子
# self.set_factor(group='CarryFactor', name='MainNearFactor3')
self.set_factor(group='MomentumFactor', name='MomentumFactor1', R=250)

# %% [markdown]
# ## 获取因子自相关性图
#
# 该图为因子在各品种上自相关性曲线（横轴为滞后阶数，纵轴为自相关性）的平均。

# %%
self.get_factor_autocorrelation()

# %% [markdown]
# ## 获取因子rank分组与收益率rank的violin plot
#
# group_num: int, default 5, 分组组数\
# period: int, default 1, 收益率周期长度\
# start: str, default None, 起始日期\
# end: str, default None，结束日期

# %%
self.get_Frank_vs_Rrank(group_num=10, period=120)

# %% [markdown]
# ## 获取每个品种的因子分布violin图

# %%
self.get_factor_distribution_per_symbol()

# %% [markdown]
# ## 因子正负相关
#
# 统计每个品种:\
# 1.因子值大于0的天数占总天数的比例\
# 2.因子值小于0的天数占总天数的比例\
# 3.上穿天数的比例\
# 4.下穿天数的比例\

# %%
self.get_factor_PN_stats()

# %% [markdown]
# ## 获取因子时序图
#
# 参数:\
# 1.period: int, 持有期

# %%
self.get_factor_time_series()
