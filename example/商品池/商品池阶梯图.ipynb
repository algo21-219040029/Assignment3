# %% [markdown]
# # 导入库

# %%
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).parent.parent)

# %%
import matplotlib.pyplot as plt
from data_manager.CommodityPoolManager import CommodityPoolManager

# %% [markdown]
# # DynamicPool3阶梯图

# %%
self = CommodityPoolManager()
dynamic_pool3_num_series = self.get_commodity_pool_time_series_plot(group='DynamicPool', name='DynamicPool3')

# %% [markdown]
# # DynamicPool4阶梯图

# %%
self = CommodityPoolManager()
dynamic_pool4_num_series = self.get_commodity_pool_time_series_plot(group='DynamicPool', name='DynamicPool4')

# %%
pct_diff1 = (dynamic_pool3_num_series - dynamic_pool4_num_series)/dynamic_pool4_num_series

# %%
pct_diff1.plot(figsize=(20, 8))
plt.grid()
plt.title("diff between dynamic pool3 and dynamic pool4 (pool3-pool4)/pool4")
plt.show()

# %%
pct_diff2 = (dynamic_pool3_num_series - dynamic_pool4_num_series)/dynamic_pool3_num_series
pct_diff2.plot(figsize=(20, 8))
plt.grid()
plt.title("diff between dynamic pool3 and dynamic pool4 (pool3-pool4)/pool3")
plt.show()
