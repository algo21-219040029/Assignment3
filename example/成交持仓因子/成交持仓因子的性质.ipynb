# %% [markdown]
# # 导入库

# %%
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).parent.parent)

# %%
os.getcwd()
# Out:
# 'D:\\LFProjects\\NewPythonProject'

# %%
from factor_test.base import BaseFactorTest

# %% [markdown]
# # 因子时序图

# %%
self = BaseFactorTest()
self.set_factor(group="TradeHoldFactor", name='BilateralTradeHoldFactor1', N=20, window=20)
self.get_factor_time_series(period=20)

# %% [markdown]
# # 因子自相关性

# %% [markdown]
# ## BilateralTradeHoldFactor1

# %%
self = BaseFactorTest()
self.set_factor(group="TradeHoldFactor", name='BilateralTradeHoldFactor1', N=5, window=1)
self.get_factor_autocorrelation()

# %%
self = BaseFactorTest()
self.set_factor(group="TradeHoldFactor", name='BilateralTradeHoldFactor1', N=20, window=1)
self.get_factor_autocorrelation()

# %%
self = BaseFactorTest()
self.set_factor(group="TradeHoldFactor", name='BilateralTradeHoldFactor1', N=20, window=20)
self.get_factor_autocorrelation()

# %% [markdown]
# ## UnilateralTradeHoldFactor1
